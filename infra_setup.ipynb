# %%
# %sql
CREATE SCHEMA IF NOT EXISTS dbr_dev_ua5816bd.team_crypto_bronze
COMMENT 'Raw ingestion and metadata';

CREATE SCHEMA IF NOT EXISTS dbr_dev_ua5816bd.team_crypto_silver
COMMENT 'Cleaned and conformed data';

# %%
# %sql
CREATE VOLUME IF NOT EXISTS dbr_dev_ua5816bd.team_crypto_bronze.raw_data;

# %%
# %sql
SHOW GRANTS ON CATALOG dbr_dev_ua5816bd;

# %% [markdown]
# ## Team schemas
# - Bronze: `dbr_dev_ua5816bd.team_crypto_bronze` (volume: `raw_data`)
# - Silver: `dbr_dev_ua5816bd.team_crypto_silver`
# - Secret scope: `team-crypto-scope` (WRITE access for all team members)
#
# Access is provided via the existing `students` group (ALL PRIVILEGES on catalog).
