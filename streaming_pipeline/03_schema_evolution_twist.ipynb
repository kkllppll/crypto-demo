# %% [markdown]
# ## Schema evolution twist — dev/test, not scheduled
# Run after the consumer (02) has been streaming for a bit.

# %%
dbutils.widgets.text("catalog", "dbr_dev_ua5816bd")
dbutils.widgets.text("silver_schema", "team_crypto_silver")

# %%
catalog = dbutils.widgets.get("catalog")
silver_schema = dbutils.widgets.get("silver_schema")
silver_ticks = f"{catalog}.{silver_schema}.ticks_prices"

# %%
from pyspark.sql import functions as F

# %% [markdown]
# Now edit `01_producer_price_ticks.ipynb`'s send cell to include `volume_24h`, rerun it once. The consumer (02) keeps running untouched - it only stores raw JSON. Then run `04_silver_prices.ipynb` again: schema inference picks up `volume_24h` automatically, no code change.

# %%
spark.table(silver_ticks).printSchema()
spark.table(silver_ticks).orderBy(F.col("event_time").desc()).limit(5).show(truncate=False)
